# %% [markdown]
# ![Screenshot from 2023-01-24 14-17-34.png](attachment:51be536e-d9a0-4a8a-91fe-6cd0f2ea116f.png)
# ![Screenshot from 2023-01-24 14-18-02.png](attachment:260ec018-f6da-40a4-a100-b955abb18b28.png)

# %%
if __name__ == '__main__':

    lst = []
    for _ in range(int(input())):
        name = input()
        score = float(input())
        lst.append([name, score])
    
    scores = []
    for ele in lst:
        scores.append(ele[1])
    
    mins=[]    
    minimum = min(scores)
    for ele in lst:
        if ele[1]==minimum:
           mins.append(ele)
    
    [lst.remove(ele) for ele in mins if ele in lst]
    
    scores = []
    for ele in lst:
        scores.append(ele[1])
    
    mins=[]
    minimum=0
    minimum = min(scores)
    for ele in lst:
        if ele[1]==minimum:
            mins.append(ele)
            
    mins.sort()
    [print(ele[0]) for ele in mins]
# Out:
#  5
#  Harsh
#  20
#  Beria
#  20
#  Varun
#  19
#  Kakunami
#  19
#  Vikas
#  21
# Beria
# Harsh
