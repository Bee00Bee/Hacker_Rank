# %% [markdown]
# ![Screenshot from 2022-11-15 11-47-25.png](attachment:eebbd56e-ba31-4549-934f-8a27c8374c69.png)

# %%
def plusMinus(arr):
    # Write your code here
    total_pos = 0
    total_neg = 0
    total_zero = 0
    for ele in arr:
        if ele > 0:
            total_pos += 1
        elif ele < 0:
            total_neg += 1
        else:
            total_zero += 1
            
    print('%0.6f'%(total_pos/len(arr)))
    print('%0.6f'%(total_neg/len(arr)))
    print('%0.6f'%(total_zero/len(arr)))

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    plusMinus(arr)
# Out:
#  4
#  1 -1 2 0 3 -5
# 0.500000
# 0.333333
# 0.166667
