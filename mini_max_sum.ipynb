# %% [markdown]
# ![Screenshot from 2022-11-15 11-50-54.png](attachment:b89aa97d-4275-4647-a9e3-cb7418420cba.png)

# %%
import itertools

def MinMaxSum(arr):
    sums = []
    lists = list(itertools.combinations(arr,4))
    for l in lists:
        sums.append(sum(l))
    print(f'{min(sums)}  {max(sums)}')
    
    
if __name__ == '__main__':
    arr = [1, 2, 4, 5, 6]
    MinMaxSum(arr)
# Out:
# 12  17
