# %% [markdown]
# ![Screenshot from 2022-11-15 11-49-00.png](attachment:2fb39091-17dc-430e-94f0-0322494c8535.png)

# %%
def staircase(n):
    i = 1
    while i<= n:
        string = ' '
        string = ' '*(n-i)
        string += i*'#'
        print(string)
        i += 1

if __name__ == '__main__':
    n = int(input())
    staircase(n)
# Out:
#  5
#     #
#    ##
#   ###
#  ####
# #####
