# %% [markdown]
# ![Screenshot from 2023-01-24 10-26-00.png](attachment:a448a07c-5bb2-41b4-b268-7af6d9d2a6be.png)

# %%
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    
    lst = []
    [lst.append(ele) for ele in arr]
    
    maximum = max(lst)
    
    lst.remove(maximum)
    
    while lst != []:
        if max(lst) == maximum:
            lst.remove(maximum)
        else:
            break
    
    print(max(lst))
# Out:
#  5
#  1 5 5 3 5
# 3
